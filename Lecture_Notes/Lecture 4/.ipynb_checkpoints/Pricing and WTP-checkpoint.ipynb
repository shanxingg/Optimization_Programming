# %% [markdown]
# ## Response Curve form the Normal Distribution
# Let's assume that the pdf of the willingness to pay is Normally distributed, i.e., with mean and variance $\mu$ and $\sigma^2$, respectively.
#
# \begin{equation}
# w(p)\sim N\left(\mu,\sigma^2\right)
# \end{equation}
#
# Market research revealed that the market potential is $M$. Customers who will buy the product are those whose willingness to pay for the product is greater than the posted price, $p$, such that.
#
# \begin{equation}
# d(p)=M \times \left[1-\Phi\left( \frac{p-\mu}{\sigma}  \right)\right]
# \end{equation}
#
# The optimization problem is then to choose the price $p^*$ that will maximize profit.
# \begin{equation}
# \text{Maximize}_p\quad d(p)\times (p-c)=M\times \left[1-\Phi\left( \frac{p-\mu}{\sigma}  \right)\right] \times (p-c)
# \end{equation}
# where $c$ is the variable cost.
#
# Recall that the CDF of the Normal distribution is
# \begin{equation}
# \frac{1}{2} \times \left[1+erf\left( \frac{p-\mu}{\sigma \sqrt{2}}   \right)   \right]
# \end{equation}

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu = 15
variance = 16
sigma = math.sqrt(variance)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
plt.plot(x,mlab.normpdf(x, mu, sigma))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math
import scipy
from math import *

mu = 15
variance = 16
sigma = math.sqrt(variance)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
plt.plot(x,(1-0.5*(1+scipy.special.erf((x-mu)/(sigma*math.sqrt(2))))))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math
import scipy
from math import *

mu = 15
variance = 16**2
c=10
sigma = math.sqrt(variance)
p = np.linspace(c, mu+2*sigma)
plt.plot(p,(1-0.5*(1+scipy.special.erf((p-mu)/(sigma*math.sqrt(2)))))*(p-c),color='C1')
plt.show()

# %%
## Homogeneous Segment
import math
import numpy as np
from math import *
from scipy.optimize import minimize_scalar
from scipy.optimize import minimize
c=10 # Marginal Cost of Production
mu=15 # mu
sigma=16 # Sigma
M=1 # Market size is normalized to one
def profit(p):
    """This is the negative profit function"""
    return -M*(1-0.5*(1+erf((p-mu)/(sigma*math.sqrt(2)))))*(p-c)
res = minimize_scalar(profit) # The routine is coded as mininization
print(-res.fun) # Return the profit level at the optimal price
print(res.x) # This is the optimal price
# Out:
# 4.01832995955
# 23.6593401883

# %% [markdown]
# ## Two Segment Case

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu1, mu2 = 15, 22
variance1,variance2 = 16, 30
sigma1 = math.sqrt(variance1)
sigma2 = math.sqrt(variance2)
x = np.linspace(mu1 - 4*sigma1, mu1 + 4*sigma1, 100)
plt.plot(x,mlab.normpdf(x, mu1, sigma1))
plt.plot(x,mlab.normpdf(x, mu2, sigma2))
plt.show()

# %% [markdown]
# ### Two Demand Functions

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math
import scipy
from math import *

mu = 15
variance = 16
sigma = math.sqrt(variance)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
plt.plot(x,(1-0.5*(1+scipy.special.erf((x-mu1)/(sigma1*math.sqrt(2))))))
plt.plot(x,(1-0.5*(1+scipy.special.erf((x-mu2)/(sigma2*math.sqrt(2))))))
plt.plot(x,0.5*((1-0.5*(1+scipy.special.erf((x-mu1)/(sigma1*math.sqrt(2))))))+0.5*(1-0.5*(1+scipy.special.erf((x-mu2)/(sigma2*math.sqrt(2))))))
plt.show()

# %% [markdown]
# ## Optimal Price with Two Segments

# %%
## This is a pricing example
## Two Segments; two different prices
## there are two segments of proportion alpha and 1-alpha, with wtp that are normally distributed with vector mu and sigma
import math
import numpy as np
from math import *
from scipy.optimize import minimize_scalar
from scipy.optimize import minimize
mu=np.array([15,22])
sigma=np.array([16,30])
alpha=.9#
M=1
def profit1(p):
    """Profit """
    return -alpha*((1-0.5*(1+erf((p[0]-mu[0])/(sigma[0]*math.sqrt(2)))))*\
                       (p[0]-c))-\
                       (1-alpha)*((1-0.5*(1+erf((p[0]-mu[1])/(sigma[1]*math.sqrt(2)))))*\
                       (p[0]-c))
sol1=minimize(profit1, [0.1, 0.1], method="BFGS")
print(-sol1.fun)
print(sol1.x)
# Out:
# 4.283271907542894
# [ 24.6123995   0.1      ]

# %% [markdown]
# # Optimal priceS with two Different Segment

# %%
## This is a pricing example
## Two Segments; two different prices
## there are two segments of proportion alpha and 1-alpha, with wtp that are normally distributed with vector mu and sigma
import math
import numpy as np
from math import *
from scipy.optimize import minimize_scalar
from scipy.optimize import minimize
mu=np.array([15,22])
sigma=np.array([16,30])
M=1
def profit2(p):
    """Profit """
    return -alpha*((1-0.5*(1+erf((p[0]-mu[0])/(sigma[0]*math.sqrt(2)))))*\
                       (p[0]-c))-\
                       (1-alpha)*((1-0.5*(1+erf((p[1]-mu[1])/(sigma[1]*math.sqrt(2)))))*\
                       (p[1]-c))
sol2=minimize(profit2, [0.1, 0.1], method="BFGS")
print(-sol2.fun)
print(sol2.x)
# Out:
# 7.900996194401795
# [ 23.6592554   36.54735083]

# %%
print(-sol2.fun/-sol1.fun)
# Out:
# 1.0201431969278332

# %% [markdown]
# ### Scrap Notebook

# %% [markdown]
# https://www.scipy-lectures.org/advanced/mathematical_optimization/index.html#full-code-examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
p = np.arange(0., 10, 0.01)

# red dashes, blue squares and green triangles
#plt.plot(p, 0.5*(1+erf((p-mu)/(sigma))))
plt.plot(p, 1-p/2)
plt.show()

# %%
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
from math import * # Needed to for erf
mu, sigma = .1, 0.1
s = np.random.normal(mu, sigma, 30000)
#count, bins, ignored = plt.hist(s, 30, normed=True)
#plt.plot(bins,1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),linewidth=2, color='r')
alpha=0.1
plt.plot(1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) )+2*1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu*2)**2 / (2 * (sigma/2)**2) ),linewidth=2, color='r')
plt.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
import random
from scipy.stats import norm
from random import uniform

fig, ax = plt.subplots()
x = np.linspace(0, 50, 1500)

random.normalvariate(15, sigma)










for i in range(3):
    m, s = uniform(-1, 1), uniform(1, 2)
    y = norm.pdf(x, loc=m, scale=s)
    current_label = f'$\mu = {m:.2}$'
    ax.plot(x, y, linewidth=2, alpha=0.6, label=current_label)
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import math

mu = 15
variance = 16
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x,mlab.normpdf(x, mu, sigma))
plt.show()
